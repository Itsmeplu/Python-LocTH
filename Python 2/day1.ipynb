# %%
import math
print(math.sqrt(5))
# Out:
# 2.23606797749979

# %%
import time

# %%
time.time()
# Out:
# 1761971567.3402722

# %%
import random

random.seed(0)
random.random()
# Out:
# 0.8444218515250481

# %%
print(random.random())
# Out:
# 0.420571580830845
